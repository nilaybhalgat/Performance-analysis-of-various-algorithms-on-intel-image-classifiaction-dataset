# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/5713.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/17374.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/2417.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/2348.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/3033.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/2434.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/13633.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/19444.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/8362.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/16633.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/16019.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/260.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/10503.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/12119.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/13992.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/15807.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/9087.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/9287.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/16022.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/16783.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/18394.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/872.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/13567.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/10835.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/15088.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/2666.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/16387.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/16740.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/19314.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/7046.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/11713.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/7207.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/7863.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/13897.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/19809.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/13221.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/3661.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/16333.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/7717.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/18423.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/138.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/18678.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/8122.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/10459.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/4963.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/18718.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/13587.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/1425.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/5369.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/15019.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/6309.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/19413.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/19215.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/11814.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/3303.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/17927.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/16848.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/5461.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/10369.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/1269.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/7236.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/18880.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/6486.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/13226.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/13557.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/7220.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/15174.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/16340.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/1711.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/3961.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/3016.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/338.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/8949.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/14591.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/15752.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/12323.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/210.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/13791.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/15614.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/15347.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/16580.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/17412.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/13046.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/18905.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/3764.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/3845.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/106.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/5724.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/19113.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/1182.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/11934.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/840.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/3889.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/9600.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/16870.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/18811.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/10784.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/2695.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/6144.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/14227.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/16521.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/10900.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/19559.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/11048.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/1208.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/11416.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/1548.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/13539.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/2308.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/6155.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/14915.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/2336.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/2785.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/2111.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/2421.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/17249.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/12379.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/10697.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/12455.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/3653.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/10238.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/10633.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/17095.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/18516.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/11710.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/10322.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/14023.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/17078.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/16631.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/2667.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/7543.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/8313.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/14839.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/7341.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/5239.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/1489.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/7327.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/17732.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/14598.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/12523.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/16195.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/14123.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/3501.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/2990.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/2089.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/18606.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/15150.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/14659.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/6434.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/3566.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/14608.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/19613.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/3098.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/15650.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/5382.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/11143.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/3182.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/12633.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/18190.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/19659.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/1589.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/13391.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/186.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/6636.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/4938.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/3244.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/1398.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/3015.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/11088.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/1701.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/19724.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/17469.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/7596.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/396.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/9378.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/12530.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/1015.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/9442.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/16482.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/7431.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/5512.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/17849.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/9118.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/10613.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/17497.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/4606.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/17259.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/3834.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/8262.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/18692.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/19739.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/11381.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/1194.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/6754.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/12597.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/18353.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/16821.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/12870.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/17568.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/10804.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/11913.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/1078.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/14479.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/15132.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/18018.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/16571.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/406.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/8818.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/8761.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/17093.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/15857.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/16905.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/15953.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/5063.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/6149.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/7008.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/10430.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/3069.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/11812.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/2188.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/18176.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/7718.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/6299.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/14134.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/5837.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/14219.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/1942.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/17801.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/16652.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/1030.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/113.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/4847.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/16437.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/15584.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/11867.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/18165.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/15852.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/12898.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/2657.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/18534.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/20013.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/13426.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/1952.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/3217.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/3619.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/9817.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/18937.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/16055.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/12779.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/7392.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/19158.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/2431.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/7200.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/5613.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/2673.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/18016.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/6946.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/1011.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/19492.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/15496.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/6426.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/11847.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/1384.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/12196.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/17540.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/3534.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/9188.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/13832.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/2962.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/7837.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/11257.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/18838.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/15943.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/9080.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/8274.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/12481.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/19553.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/19823.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/14627.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/13154.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/16589.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/17865.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/782.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/249.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/11823.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/5588.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/15862.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/2527.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/5624.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/16139.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/11649.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/15373.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/18384.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/8387.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/2267.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/5948.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/14994.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/1731.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/14537.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/9770.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/3660.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/5794.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/13068.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/1754.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/18721.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/19489.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/3492.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/10927.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/11801.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/8003.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/16253.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/3347.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/14106.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/8708.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/15465.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/18429.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/2754.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/11236.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/6991.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/6038.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/358.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/9749.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/12217.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/8871.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/7529.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/10661.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/17679.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/3571.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/16258.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/3247.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/8063.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/1477.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/8294.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/17305.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/2523.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/13401.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/14002.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/6182.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/1361.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/14171.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/18217.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/3546.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/10687.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/7626.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/17615.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/6631.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/17970.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/26.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/29.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/19970.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/538.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/19882.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/6136.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/10540.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/14643.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/19891.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/8528.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/11944.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/17313.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/8527.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/14652.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/11506.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/8974.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/9926.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/17725.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/16516.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/2.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/9447.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/4996.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/19335.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/14097.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/1142.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/50.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/19130.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/10222.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/17463.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/11717.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/12806.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/7618.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/10662.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/10085.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/14143.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/16352.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/10728.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/18822.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/3340.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/10777.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/14482.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/17413.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/5893.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/4382.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/19755.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/16192.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/11178.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/17285.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/17439.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/19961.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/824.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/5815.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/7216.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/18457.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/197.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/10260.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/8055.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/9707.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/6815.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/2366.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/1100.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/8754.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/151.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/16367.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/6977.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/5141.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/15680.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/2212.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/8350.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/4142.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/18437.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/15332.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/12206.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/1599.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/4086.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/11470.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/10524.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/19338.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/8253.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/3927.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/1230.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/16596.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/8293.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/13531.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/12310.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/14305.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/7523.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/11714.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/10514.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/11002.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/11852.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/15138.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/3894.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/15797.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/8130.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/19909.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/250.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/6508.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/3181.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/10408.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/15432.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/8336.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/6515.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/14015.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/7367.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/1121.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/11459.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/10916.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/14274.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/1703.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/3123.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/2782.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/8727.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/12319.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/9489.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/1385.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/7499.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/620.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/356.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/4922.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/6356.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/10569.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/11906.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/4897.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/3908.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/19862.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/18865.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/19017.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/2301.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/15363.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/11246.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/8631.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/7303.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/5447.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/5039.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/12277.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/15509.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/14798.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/1424.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/19212.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/16572.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/1280.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/15311.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/12161.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/2675.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/3760.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/2916.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/9114.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/13233.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/8021.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/3505.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/18965.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/15499.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/17119.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/5081.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/10313.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/19829.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/19524.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/12434.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/11836.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/9468.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/16370.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/13985.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/7006.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/19031.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/17675.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/5359.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/12771.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/10335.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/11417.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/14322.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/11976.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/8102.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/10851.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/1407.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/11064.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/12449.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/18313.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/2757.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/8311.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/12238.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/3273.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/2935.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/10643.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/15592.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/2881.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/6240.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/9362.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/8543.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/992.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/12857.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/6996.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/8256.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/9934.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/12780.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/3202.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/10097.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/19147.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/13442.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/14332.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/3643.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/11116.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/13218.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/13151.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/17591.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/19331.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/1576.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/8919.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/4978.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/2965.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/15898.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/9595.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/14280.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/624.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/8999.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/6393.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/5677.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/17139.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/17137.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/1073.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/3901.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/2353.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/9798.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/3222.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/723.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/1537.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/1031.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/2848.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/5629.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/13496.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/1849.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/3503.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/14408.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/4998.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/2472.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/10070.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/18372.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/5118.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/13588.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/11650.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/14399.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/844.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/370.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/5593.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/3204.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/10610.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/2987.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/19145.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/4511.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/4279.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/6078.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/19515.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/3724.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/17652.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/4230.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/12074.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/8717.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/19420.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/3543.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/4556.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/6152.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/2344.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/10331.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/18452.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/10588.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/1472.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/8995.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/10063.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/10958.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/18060.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/6679.jpg
# /kaggle/input/intel-image-classification/seg_train/seg_train/street/19772.jpg
# ...
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/21378.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/21414.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/23885.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/23456.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/23587.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/22664.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/20300.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/22127.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/21197.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/24041.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/22083.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/20402.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/21258.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/22511.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/21462.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/22528.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/23423.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/24309.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/24018.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/21442.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/22730.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/21557.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/21006.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/23124.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/22439.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/21237.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/20316.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/24111.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/21393.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/22501.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/22807.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/23119.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/21263.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/21730.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/21714.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/22711.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/24189.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/24325.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/22246.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/23641.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/21729.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/21073.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/21037.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/21481.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/20694.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/22353.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/21898.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/21737.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/23624.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/20342.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/24122.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/20834.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/20240.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/23947.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/22920.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/23336.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/20076.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/22350.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/24158.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/24076.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/24295.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/22740.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/21428.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/20273.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/24099.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/21607.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/23841.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/21812.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/22719.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/21138.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/20696.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/20138.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/24266.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/21306.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/20371.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/21662.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/22679.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/23649.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/20640.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/21639.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/21870.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/22628.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/23974.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/20722.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/21227.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/22102.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/20595.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/20672.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/23576.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/23275.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/23400.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/21456.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/24155.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/22616.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/23638.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/23192.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/20841.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/21860.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/23006.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/22354.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/20114.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/20879.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/22262.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/20704.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/20687.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/21655.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/22154.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/20333.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/20647.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/22881.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/20999.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/23293.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/22824.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/23623.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/20172.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/20889.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/23042.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/21740.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/23165.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/22385.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/23901.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/21903.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/20848.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/23248.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/20905.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/20955.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/21957.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/20494.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/20269.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/23679.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/23209.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/23969.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/22484.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/21234.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/23705.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/20753.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/21837.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/22437.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/21638.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/21624.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/21014.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/23452.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/22012.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/20305.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/20081.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/22620.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/23826.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/21710.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/21797.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/21272.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/20165.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/20946.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/23105.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/22168.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/22147.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/21761.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/23381.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/23756.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/22543.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/22508.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/21993.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/20975.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/24301.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/23408.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/20840.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/22718.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/21130.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/22389.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/20893.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/21756.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/23205.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/22589.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/24201.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/20148.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/20281.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/22085.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/22565.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/23976.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/23806.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/21507.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/22220.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/21999.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/20341.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/24180.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/20419.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/22337.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/22867.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/22107.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/21121.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/20283.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/20909.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/23489.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/20644.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/20890.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/22393.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/23162.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/21936.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/21405.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/22977.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/23759.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/20649.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/23222.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/20513.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/21054.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/21807.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/22661.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/20285.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/21569.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/22432.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/22875.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/21328.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/24055.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/24174.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/20695.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/21217.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/22746.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/21635.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/22048.jpg
# /kaggle/input/intel-image-classification/seg_test/seg_test/sea/22066.jpg

# %%
import numpy as np
import os
from sklearn.metrics import confusion_matrix
import seaborn as sn; sn.set(font_scale=1.4)
from sklearn.utils import shuffle           
import matplotlib.pyplot as plt             
import cv2                                 
import tensorflow as tf                
from tqdm import tqdm
from sklearn.externals import joblib
from skimage.feature import hog
from skimage.io import imread
from skimage.transform import rescale
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import SGDClassifier
from sklearn.model_selection import cross_val_predict
from sklearn.preprocessing import StandardScaler
import skimage
from sklearn.preprocessing import StandardScaler
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
class_names = ['mountain', 'street', 'glacier', 'buildings', 'sea', 'forest']
class_names_label = {class_name:i for i, class_name in enumerate(class_names)}

nb_classes = len(class_names)

IMAGE_SIZE = (100, 100)

# %%
def load_data():
    """
        Load the data:
            - 14,034 images to train the network.
            - 3,000 images to evaluate how accurately the network learned to classify images.
    """
    
    datasets = ['../input/intel-image-classification/seg_train/seg_train', '../input/intel-image-classification/seg_test/seg_test']
    output = []
    
    # Iterate through training and test sets
    for dataset in datasets:
        
        images = []
        labels = []
        
        print("Loading {}".format(dataset))
        
        # Iterate through each folder corresponding to a category
        for folder in os.listdir(dataset):
            label = class_names_label[folder]
            
            # Iterate through each image in our folder
            for file in tqdm(os.listdir(os.path.join(dataset, folder))):
                
                # Get the path name of the image
                img_path = os.path.join(os.path.join(dataset, folder), file)
                
                # Open and resize the img
                image = cv2.imread(img_path)
                image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
                image = cv2.resize(image, IMAGE_SIZE) 
                
                # Append the image and its corresponding label to the output
                images.append(image)
                labels.append(label)
                
        images = np.array(images, dtype = 'float32')
        labels = np.array(labels, dtype = 'int32')   
        print(images.shape)
        output.append((images, labels))

    return output

# %%
(train_images, train_labels), (test_images, test_labels) = load_data()

train_images, train_labels = shuffle(train_images, train_labels, random_state=25)
# Out:
#   1%|          | 23/2382 [00:00<00:10, 228.88it/s]
# Loading ../input/intel-image-classification/seg_train/seg_train
# 100%|██████████| 2382/2382 [00:07<00:00, 329.55it/s]
# 100%|██████████| 2271/2271 [00:06<00:00, 348.82it/s]
# 100%|██████████| 2512/2512 [00:06<00:00, 379.11it/s]
# 100%|██████████| 2191/2191 [00:05<00:00, 366.18it/s]
# 100%|██████████| 2404/2404 [00:06<00:00, 371.20it/s]
# 100%|██████████| 2274/2274 [00:06<00:00, 375.62it/s]
#   7%|▋         | 34/501 [00:00<00:01, 339.24it/s]
# (14034, 100, 100, 3)
# Loading ../input/intel-image-classification/seg_test/seg_test
# 100%|██████████| 501/501 [00:01<00:00, 385.20it/s]
# 100%|██████████| 474/474 [00:01<00:00, 367.76it/s]
# 100%|██████████| 525/525 [00:01<00:00, 399.47it/s]
# 100%|██████████| 437/437 [00:01<00:00, 392.14it/s]
# 100%|██████████| 553/553 [00:01<00:00, 388.01it/s]
# 100%|██████████| 510/510 [00:01<00:00, 398.95it/s]
# (3000, 100, 100, 3)

# %%
n_train = train_labels.shape[0]
n_test = test_labels.shape[0]

print ("Number of training examples: {}".format(n_train))
print ("Number of testing examples: {}".format(n_test))
print ("Each image is of size: {}".format(IMAGE_SIZE))
# Out:
# Number of training examples: 14034
# Number of testing examples: 3000
# Each image is of size: (100, 100)

# %%
from PIL import Image

def compute_average_image_color(img):
   # width, height = img.size

    r_total = 0
    g_total = 0
    b_total = 0
    

    count = 0
    for file in tqdm(os.listdir(img)):
        loc = Image.open(os.path.join(img,file))
        width, height = loc.size
        for x in range(0, width):
            for y in range(0, height):
                r, g, b = loc.getpixel((x,y))
                r_total += r
                g_total += g
                b_total += b
                
    c =140340000
    return (r_total/c, g_total/c, b_total/c)

forest = '../input/intel-image-classification/seg_train/seg_train/forest'
#img = img.resize((50,50))  # Small optimization
average_color_forest = compute_average_image_color(forest)
print(average_color_forest)

glacier = '../input/intel-image-classification/seg_train/seg_train/glacier'
#img = img.resize((50,50))  # Small optimization
average_color_glacier = compute_average_image_color(glacier)
print(average_color_glacier)


buildings = '../input/intel-image-classification/seg_train/seg_train/buildings'
#img = img.resize((50,50))  # Small optimization
average_color_buildings = compute_average_image_color(buildings)
print(average_color_buildings)

mountain = '../input/intel-image-classification/seg_train/seg_train/mountain'
#img = img.resize((50,50))  # Small optimization
average_color_mountain = compute_average_image_color(mountain)
print(average_color_mountain)

street = '../input/intel-image-classification/seg_train/seg_train/street'
#img = img.resize((50,50))  # Small optimization
average_color_street = compute_average_image_color(street)
print(average_color_street)

sea = '../input/intel-image-classification/seg_train/seg_train/sea'
#img = img.resize((50,50))  # Small optimization
average_color_sea = compute_average_image_color(sea)
print(average_color_sea)
# Out:
# 100%|██████████| 2271/2271 [01:19<00:00, 28.48it/s]
#   0%|          | 3/2404 [00:00<01:20, 29.71it/s]
# (30.47355997577312, 33.04300612797492, 22.507051809890267)
# 100%|██████████| 2404/2404 [01:23<00:00, 28.87it/s]
#   0%|          | 3/2191 [00:00<01:13, 29.61it/s]
# (46.397960218041895, 52.19612250961949, 57.14842568049024)
# 100%|██████████| 2191/2191 [01:17<00:00, 28.37it/s]
#   0%|          | 3/2512 [00:00<01:24, 29.61it/s]
# (40.33540430383355, 41.10398794356563, 41.54086184979336)
# 100%|██████████| 2512/2512 [01:27<00:00, 28.75it/s]
#   0%|          | 3/2382 [00:00<01:25, 27.72it/s]
# (45.143694976485676, 49.55029859626621, 52.28102222459741)
# 100%|██████████| 2382/2382 [01:23<00:00, 28.45it/s]
#   0%|          | 3/2274 [00:00<01:17, 29.20it/s]
# (41.730623200798064, 40.401061016103746, 39.036230312099185)
# 100%|██████████| 2274/2274 [01:19<00:00, 28.58it/s]
# (42.59208175146074, 46.02569557503207, 47.723552037907936)

# %%
import seaborn as sns
plt.figure(figsize=(10,6))
sns.distplot(average_color_glacier[0], label="glacier")
sns.distplot(average_color_mountain[0],label="mountain")
sns.distplot(average_color_sea[0], label="sea")
sns.distplot(average_color_street[0], label="street")
sns.distplot(average_color_forest[0], label="forest")
sns.distplot(average_color_buildings[0], label="buildings")
plt.title("Red color distribution")
plt.legend()
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)

# %%
plt.figure(figsize=(10,6))
sns.distplot(average_color_glacier[1], label="glacier")
sns.distplot(average_color_mountain[1],label="mountain")
sns.distplot(average_color_sea[1], label="sea")
sns.distplot(average_color_street[1], label="street")
sns.distplot(average_color_forest[1], label="forest")
sns.distplot(average_color_buildings[1], label="buildings")
plt.title("Green color distribution")
plt.legend()
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)

# %%
plt.figure(figsize=(10,6))
sns.distplot(average_color_glacier[2], label="glacier")
sns.distplot(average_color_mountain[2],label="mountain")
sns.distplot(average_color_sea[2], label="sea")
sns.distplot(average_color_street[2], label="street")
sns.distplot(average_color_forest[2], label="forest")
sns.distplot(average_color_buildings[2], label="buildings")
plt.title("Blue color distribution")
plt.legend()
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)

# %%
labels = 'Red', 'Green' , 'Blue'
colors = ['Red', 'Green', 'Blue' ]
explode = (0.1, 0, 0)  # explode 1st slice



# Plot
plt.legend(title="Forest")
plt.pie(average_color_forest, explode=explode, labels=labels, colors=colors,
autopct='%1.1f%%', shadow=True, startangle=140)
plt.axis('equal')
plt.show()

plt.legend(title="glacier")
plt.pie(average_color_glacier, explode=explode, labels=labels, colors=colors,
autopct='%1.1f%%', shadow=True, startangle=140)
plt.axis('equal')
plt.show()

plt.legend(title="buildings")
plt.pie(average_color_buildings, explode=explode, labels=labels, colors=colors,
autopct='%1.1f%%', shadow=True, startangle=140)
plt.axis('equal')
plt.show()

plt.legend(title="mountain")
plt.pie(average_color_mountain, explode=explode, labels=labels, colors=colors,
autopct='%1.1f%%', shadow=True, startangle=140)
plt.axis('equal')
plt.show()

plt.legend(title="street")
plt.pie(average_color_street, explode=explode, labels=labels, colors=colors,
autopct='%1.1f%%', shadow=True, startangle=140)
plt.axis('equal')
plt.show()

plt.legend(title="sea")
plt.pie(average_color_sea, explode=explode, labels=labels, colors=colors,
autopct='%1.1f%%', shadow=True, startangle=140)
plt.axis('equal')
plt.show()

# %%
import pandas as pd

_, train_counts = np.unique(train_labels, return_counts=True)
_, test_counts = np.unique(test_labels, return_counts=True)
pd.DataFrame({'train': train_counts,
                    'test': test_counts}, 
             index=class_names
            ).plot.bar()
plt.show()

# %%
plt.pie(train_counts,
        explode=(0, 0, 0, 0, 0, 0) , 
        labels=class_names,
        autopct='%1.1f%%')
plt.axis('equal')
plt.title('Proportion of each observed category')
plt.show()

# %%
train_images = train_images / 255.0 
test_images = test_images / 255.0

# %%
def display_random_image(class_names, images, labels):
    """
        Display a random image from the images array and its correspond label from the labels array.
    """
    
    index = np.random.randint(images.shape[0])
    plt.figure()
    plt.imshow(images[index])
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.title('Image #{} : '.format(index) + class_names[labels[index]])
    plt.show()

# %%
display_random_image(class_names, train_images, train_labels)

# %%
def display_examples(class_names, images, labels):
    """
        Display 25 images from the images array with its corresponding labels
    """
    
    fig = plt.figure(figsize=(10,10))
    fig.suptitle("Some examples of images of the dataset", fontsize=16)
    for i in range(25):
        plt.subplot(5,5,i+1)
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        plt.imshow(images[i], cmap=plt.cm.binary)
        plt.xlabel(class_names[labels[i]])
    plt.show()
display_examples(class_names, train_images, train_labels)
